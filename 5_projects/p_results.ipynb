# %%
from p import check_clustering_er, generate_community_graph, draw_community_graph, plot_ws_clustering_vs_p

# %%
check_clustering_er(n=2000, p=0.05, trials=5)
# Out:
# Trial 1/5: C = 0.04985
# Trial 2/5: C = 0.05024
# Trial 3/5: C = 0.04999
# Trial 4/5: C = 0.05022
# Trial 5/5: C = 0.04979
#
# --- Results ---
# Analytical expectation:  C = p = 0.05
# Simulated mean:          C = 0.05002
# Standard deviation:      0.00018

# %%
G, community = generate_community_graph(num_communities=4, N=20, p_in=0.3, p_out=0.01)
draw_community_graph(G, community)

# %%
plot_ws_clustering_vs_p(n=100, k=4, trials=100)
