# %%
from exercises import exercise1, exercise2, exercise3, exercise4, exercise5

# %%
exercise1()

# %%
exercise2(p=0.4)
# Out:
# Pareto Rule Analysis (TOST Equivalence Test):
# - Based on 500 simulations
# - Top 20% accounts for: 44.95% ± 0.07% (95% CI)
# - Standard deviation: 0.78%
#
# --- TOST Equivalence Test (α=0.05) ---
# Equivalence range: [0.75, 0.85]
#   Test 1 - H1: mean > 0.75
#     t = -865.4387, p = 1.000000 ✗
#   Test 2 - H1: mean < 0.85
#     t = -1153.4384, p = 0.000000 ✓
#   Combined p-value: 1.000000
#
# ✗ EQUIVALENCE NOT DEMONSTRATED
#   Proportion is not close enough to 0.8
#   → PARETO PRINCIPLE DOES NOT HOLD

# %%
exercise3(x_min=1, alpha=4)

# %%
exercise4(a=2)
# Out:
# Pareto Rule Analysis (TOST Equivalence Test):
# - Based on 500 simulations
# - Top 20% accounts for: 80.77% ± 0.58% (95% CI)
# - Standard deviation: 6.64%
#
# --- TOST Equivalence Test (α=0.05) ---
# Equivalence range: [0.75, 0.85]
#   Test 1 - H1: mean > 0.75
#     t = 19.4205, p = 0.000000 ✓
#   Test 2 - H1: mean < 0.85
#     t = -14.2447, p = 0.000000 ✓
#   Combined p-value: 0.000000
#
# ✓ EQUIVALENCE DEMONSTRATED
#   Proportion is statistically equivalent to 0.8
#   → PARETO PRINCIPLE HOLDS

# %%
exercise5(n=500, m=3, p=0.01)
