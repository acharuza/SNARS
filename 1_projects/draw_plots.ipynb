# %%
from functions import draw_square_lattice, draw_chain, draw_complete_graph, draw_directed_graph, draw_weighted_graph

# %%
# seed
seed = 123

# %% [markdown]
# ## P1.1

# %%
draw_square_lattice(10, 5)

# %% [markdown]
# ## P 1.2

# %%
draw_chain(16)

# %% [markdown]
# ## P 1.3

# %%
draw_complete_graph(7)

# %% [markdown]
# ## P 1.4
# graph and weights are randomized

# %%
draw_weighted_graph(n_vertices=7, n_edges=9, seed=seed)

# %% [markdown]
# # P 1.5
# graph and directions are randomized

# %%
draw_directed_graph(n_vertices=9, n_edges=7, seed=seed)
