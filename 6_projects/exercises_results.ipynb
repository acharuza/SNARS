# %%
from ba_model import averaged_histogram, estimate_alpha, plot_ki_vs_theory

# %%
_, _ = averaged_histogram(T=100, m0=3, m=2, runs=1000, bins=30)

# %%
_ = estimate_alpha(T=100, m0=3, m=2, runs=1000, bins=30)
# Out:
# Estimated α ≈ 3.026
# Theoretical α = 3 (BA model)

# %%
plot_ki_vs_theory(T=200, m0=5, m=2, runs=1000, nodes_to_plot=None)
