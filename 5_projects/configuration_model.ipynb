# %%
from configuration_model import configuration_model, draw_configuration_model

# %%
deg_sequences = [
    [3, 2, 1, 2, 0, 2],
    [1, 1, 0, 2, 2, 1],
    [5, 1, 1, 0, 2, 0],
    [5, 2, 0, 0, 1, 0],
    [5, 0, 1, 1, 0, 0],
    [0, 2, 1, 2, 1, 0],
    [1, 1, 2, 0, 1, 1]
]

# %%
for deg_sequence in deg_sequences:
    G = configuration_model(deg_sequence)
    if isinstance(G, str):
        print(deg_sequence, G)
    else:
        print(deg_sequence, "Graph drawn successfully")
        draw_configuration_model(G)
# Out:
# [3, 2, 1, 2, 0, 2] Graph drawn successfully
# [1, 1, 0, 2, 2, 1] A simple graph cannot be drawn with given degree sequence
# [5, 1, 1, 0, 2, 0] A simple graph cannot be drawn with given degree sequence
# [5, 2, 0, 0, 1, 0] A simple graph cannot be drawn with given degree sequence
# [5, 0, 1, 1, 0, 0] A simple graph cannot be drawn with given degree sequence
# [0, 2, 1, 2, 1, 0] Graph drawn successfully
# [1, 1, 2, 0, 1, 1] Graph drawn successfully
