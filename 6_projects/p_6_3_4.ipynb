# %%
from p_6_3_4 import plot_models_avg_vs_theory

# %%
plot_models_avg_vs_theory(T=200, m0=3, m=2, runs=500, model="A")

# %%
plot_models_avg_vs_theory(T=200, N_B=50, m=2, runs=500, model="B", sample_nodes=4)
